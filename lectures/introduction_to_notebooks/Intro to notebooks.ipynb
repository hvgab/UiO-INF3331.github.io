# %% [markdown]
# # Using Jupyter Notebooks

# %% [markdown]
# # Idealized computational research
#
# 1. Write code
# 2. Run code
# 3. Make figures
# 4. Write paper
# 5. Share and reproduce

# %% [markdown]
# In reality, people tend to jump back and forth in a much more interactive manner!

# %% [markdown]
# A Jupyter notebook is a browser based and interactive way to run code. A Python notebook allows you to run code one segment at the time. Once executed, any outputs are printed directly underneath the input of the cell.

# %%
4 + 4
# Out:
# 8

# %%
5 % 2
# Out:
# 1

# %% [markdown]
# # Markdown
#
# One of the major advantages of notebooks is the ability to interleave code, results and explanatory text. The explanatory text can be edited in the document in the same way as you would edit code. Once executed, it changes to a rendered view. As long as it is in a live notebook, it can be edited at any time by simply double-clicking the cell.
#
# To indicate that a cell is explanatory text, the type of the cell should be changed from the default "code" type, to the "markdown" type. Markdown is the name of the syntax used to write the explanatory text.

# %% [markdown]
# ## Including equations
#
# In markdown, math can be typeset using LaTeX' math syntax. Inline equations are indicated by surrounding the equation in dollar signs (`$ type equation here $`). For example: $ i\hbar {\frac {\partial }{\partial t}}\Psi (\mathbf {r} ,t)={\hat {H}}\Psi (\mathbf {r} ,t) $. You can also add equation blocks by surrounding the equation(s) with double dollar signs (`$$ type equation(s) here $$`):
# $$
# i\hbar {\frac {\partial }{\partial t}}\Psi (\mathbf {r} ,t)={\hat {H}}\Psi (\mathbf {r} ,t)
# $$
#
# For a full overview of the markdown syntax in notebooks, see http://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/rstversions/Working%20With%20Markdown%20Cells.html

# %% [markdown]
# # Plotting

# %%
# First line is only needed if you use matplotlib in a Notebook:
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from matplotlib.patches import Polygon

a, b = 2, 9  # integral limits

fig, ax = plt.subplots()
plt.plot(x, y, 'r', linewidth=2)
plt.ylim(ymin=0)

# Make the shaded region
ix = np.linspace(a, b)
iy = func(ix)
verts = [(a, 0)] + list(zip(ix, iy)) + [(b, 0)]
poly = Polygon(verts, facecolor='0.9', edgecolor='0.5')
ax.add_patch(poly)

plt.text(0.5 * (a + b), 30, r"$\int_a^b f(x)\mathrm{d}x$",
         horizontalalignment='center', fontsize=20)

plt.figtext(0.9, 0.05, '$x$')
plt.figtext(0.1, 0.9, '$y$')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')

ax.set_xticks((a, b))
ax.set_xticklabels(('$a$', '$b$'))
ax.set_yticks([])

plt.show()

# %% [markdown]
# ## Plotting image data

# %%
from todo import fractional_mandelbrot, pretty_plot


# x coordinates
x = np.linspace(-2.25, 0.75, 1024)
# y coordinates
y = np.linspace(-1.25, 1.25, 1024)

fractal = fractional_mandelbrot(x, y, 200, 2.0 ** 40)
pretty_plot(fractal)

# %%
# detail shot:
x_detail = np.linspace(-0.749, -0.748, 1024)
y_detail = np.linspace(0.065, 0.066, 1024)

detail_fractal = fractional_mandelbrot(x_detail, y_detail, 2048, 2.0 ** 40)
pretty_plot(detail_fractal)

# %% [markdown]
# ## 3D plots

# %%
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm

fig = plt.figure()
ax = fig.gca(projection='3d')
X, Y, Z = axes3d.get_test_data(0.05)
ax.plot_surface(X, Y, Z, rstride=8, cstride=8, alpha=0.3)
cset = ax.contourf(X, Y, Z, zdir='z', offset=-100, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='x', offset=-40, cmap=cm.coolwarm)
cset = ax.contourf(X, Y, Z, zdir='y', offset=40, cmap=cm.coolwarm)

ax.set_xlabel('X')
ax.set_xlim(-40, 40)
ax.set_ylabel('Y')
ax.set_ylim(-40, 40)
ax.set_zlabel('Z')
ax.set_zlim(-100, 100)

plt.show()

# %% [markdown]
# # How does Notebooks work?

# %% [markdown]
# ![Notebook data flow](notebook_components.png)

# %% [markdown]
# # Typical use-pattern

# %% [markdown]
# 1. Explore an idea interactively in a Notebook
# 2. Build/add to a library based on what you learn
# 3. Record and collaborate on analyses in Notebooks
# 4. Document, demonstrate, and share in Notebooks
# 5. Computational companions, reproducible papers

# %% [markdown]
# # Other capabilities

# %% [markdown]
# Can execute terminal calls, by prefix the commands with an exlamation point:

# %%
# !ls
# Out:
# Intro to IPython.ipynb
# Intro to notebooks.ipynb
# Sampling_Theorem.ipynb
# notebook_components.png
# todo.py

# %% [markdown]
# Get help:

# %%
?

# %%
import collections
collections.namedtuple?

# %%
# %quickref

# %% [markdown]
# `%quickref` is one of several *magics*, like `%matplotlib` as seen before.
